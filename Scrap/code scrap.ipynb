# %%
from icrawler.builtin import GoogleImageCrawler

google_crawler = GoogleImageCrawler(
    parser_threads=2,
    downloader_threads=4,
    storage={'root_dir': 'C:/Users/Dell/Desktop/ScrapImage_Police'}
)

for keyword in ['vehicule police']:
    google_crawler.crawl(
        keyword=keyword, max_num=2000, min_size=(200, 200), file_idx_offset='auto')
    # set `file_idx_offset` to 'auto' will prevent naming the 5 images
    # of dog from 000001.jpg to 000005.jpg, but naming it from 000006.jpg.
# Out:
# 2019-09-11 11:57:29,684 - WARNING - icrawler.crawler - Due to Google's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000. If you really want to get more than 1000 results, you can specify different date ranges.
# 2019-09-11 11:57:29,700 - INFO - icrawler.crawler - start crawling...
# 2019-09-11 11:57:29,702 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-09-11 11:57:29,704 - INFO - icrawler.crawler - starting 2 parser threads...
# 2019-09-11 11:57:29,707 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2019-09-11 11:57:30,262 - INFO - parser - parsing result page https://www.google.com/search?q=vehicule+police&ijn=1&start=100&tbs=&tbm=isch
# 2019-09-11 11:57:30,313 - INFO - parser - parsing result page https://www.google.com/search?q=vehicule+police&ijn=0&start=0&tbs=&tbm=isch
# ...
